# %%
import os
import re
from datetime import *
import pandas as pd
import baltic as bt

# %%
# I want to pull traits information from the DTA and match to Continuous phylogeography
# Luckily, the cont phyl is a strictly bifurcating tree, which means each node1 is seen twice
# So I could parse the DTA by object and then have a new row for each node.children

# %%
# for each node, make a list of the children
# For each child, add a row
# node 1 is the node
# node 2 is the child
# start date
# end date
# start node flyway, etc
# end node flyway, etc

# %%
# Fetch tree from the provided URL
# treeFile = "../../test_continuous/dates_added/wi_824_allwidt_MCC.tree"
# treeFile = "../SERAPHIM/nov2021-2024_no-suliformes/process_dta/NAm_wild-aves_nov2021-2024_no-suliformes_ha_emptree-contphyl_flyway-order-latgrp_MCC.tree"
# treeFile = "../BEAST/continuous_phylogeography/results/2025-09-24_nov2021-2024_no-suliformes_ha_contphyl_order-DTA_thorney/NAm_wild-aves_nov2021-2024_contphyl_order-DTA_2025-09-24_MCC.tree"
# treeFile = "../SERAPHIM/nov2021-2024_no-suliformes_contphyl-orderDTA/NAm_wild-aves_nov2021-2024_contphyl_order-DTA_tinytest.tree"
# treeFile = "../SERAPHIM/nov2021-2024_no-suliformes_contphyl-orderDTA/NAm_wild-aves_nov2021-2024_contphyl_order-DTA_mediumtest.tree"
# treeFile = "../SERAPHIM/nov2021-2024_no-suliformes_contphyl-orderDTA/NAm_wild-aves_nov2021-2024_contphyl_order-DTA_2025-09-24_MCC.tree"
# treeFile="../SERAPHIM/nov2021-2024_no-suliformes/NAm_wild-aves_nov2021-2024_no-suliformes_ha_contphyl_2025-08-18_MCC.tree"
# treeFile = "../SERAPHIM/nov2021-2024_no-suliformes_contphyl-duckgoose-DTA/NAm_wild-aves_nov2021-2024_no-suliformes_ha_contphyl_duckgoose-DTA_MCC.tree"
# treeFile = "../SERAPHIM/nov2021-2024_no-suliformes_DTA/order_dta/NAm_wild-aves_nov2021-2024_contphyl_order-DTA_2025-09-24_MCC.tree"
# treeFile = "../SERAPHIM/nov2021-2024_no-suliformes_DTA/duckduckgoose_dta/NAm_wild-aves_nov2021-2024_no-suliformes_ha_contphyl_duckgoose-DTA_MCC.tree"
# treeFile = "../../H5N5-mini-project/SERAPHIM/A6_concat-genome_traits_2026-03-01_MCC_renamed.tree"
# treeFile = "../../H5N5-mini-project/SERAPHIM/A6_concat-genome_traits_2026-03-10_MCC.tree"
# treeFile = "../SERAPHIM/main-intro_equal-time-host-3000/main-intro_equal-time-host-3000_ha_traits_MCC.tree"
# treeFile = "../SERAPHIM/main-intro_equal-time-host-1000/main-intro_equal-time-host-1000_ha_traits_MCC.tree"
# treeFile = "../SERAPHIM/main-intro_prop-time-loc/main-intro_prop-time-loc_ha_traits_noLP_MCC.tree"
# treeFile = "../SERAPHIM/main-intro_prop-time-host/main-intro_prop-time-host_ha_traits_noLP_MCC.tree"
# treeFile = "../SERAPHIM/main-intro_liveharvest/main-intro_liveharvest_ha_traits_MCC.tree"
# treeFile = "../../H5-genotypes/SERAPHIM/h5_A1_A2_exponential_traits/A1_A2_ha_exponential_traits_MCC.tree"
# treeFile = "../../H5-genotypes/SERAPHIM/h5_A3_exponential_traits/A3_ha_exponential_traits_MCC.tree"
# treeFile = "../../H5-genotypes/SERAPHIM/h5_B3.2_exponential_traits/B3.2_ha_exponential_traits_MCC.tree"
# treeFile = "../../H5-genotypes/SERAPHIM/h5_B3.6_exponential_traits/B3.6_ha_exponential_traits_MCC.tree"
# treeFile = "../../H5-genotypes/SERAPHIM/h5_C2.1_exponential_traits/C2.1_ha_exponential_traits_MCC.tree"
# treeFile = "../../H5-genotypes/SERAPHIM/h5_D1.1_exponential_traits/D1.1_ha_exponential_traits_MCC.tree"
# treeFile = "../SERAPHIM/main-intro_equal-time-loc/main-intro_equal-time-location_ha_traits_2026-05-27_MCC.tree"
# treeFile = "../../H5N5-seabird-phylo/BEAST/cont-phyl_dta/results/2026-07-09_A6_concat_genome_traits/A6_concat-gen_traits_2026-07-09_MCC.tree"
treeFile = "../../H5N5-seabird-phylo/BEAST/cont-phyl_dta/results/2026-08-04_A6_concat_genome_traits_TEST/A6_concat-gen_traits_2026-08-04_MCC.tree"

# Load the tree using Baltic
tree = bt.loadNexus(treeFile)
tree.treeStats()  # Report stats about the tree
# Out:
# Tree height: 6.003206
# Tree length: 113.765981
# strictly bifurcating tree
#
# Numbers of objects in tree: 723 (361 nodes and 362 leaves)

# %%
label_count = 0

for k in tree.Objects:
    k.label = label_count
    label_count += 1

# %%
print(tree.Objects[6].traits.keys())
# Out:
# dict_keys(['host.rate_median', 'location.rate_median', 'height_median', 'region.rate_median', 'location.rate', 'host.prob', 'host', 'length_median', 'height', 'location2_median', 'region.rate', 'location1_median', 'length', 'posterior', 'host.rate', 'region.prob', 'location1', 'location2', 'region', 'height_range', 'host.set.prob', 'location1_range', 'region.set.prob', 'region.rate_range', 'host.rate_range', 'location2_range', 'length_range', 'location1_80%HPD_4', 'location1_80%HPD_3', 'location1_80%HPD_2', 'location1_80%HPD_1', 'length_95%_HPD', 'host.rate_95%_HPD', 'location1_80%HPD_5', 'height_95%_HPD', 'host.set', 'region.set', 'location.rate_95%_HPD', 'location2_80%HPD_1', 'location2_80%HPD_2', 'location2_80%HPD_3', 'location2_80%HPD_4', 'location2_80%HPD_5', 'region.rate_95%_HPD', 'location.rate_range'])

# %%
def nexus_to_metadata(tree, MRSD):
    
    metadata = []
    # count = 0
    
    for obj in tree.Objects:
        children = []
    
        # if count < 10:
        if obj.is_node():
            children.extend(obj.children) # Use .extend instead of .append, the former makes a flat list while the latter appends a list into the list
            node1 = obj.label
            startYear = MRSD - obj.traits["height"]
            length = obj.traits["length"]
            # startFly = obj.traits["flyway"]
            startLatGrp = obj.traits["region"]
            # startOrder = obj.traits["corrected_order"]
            startOrder = obj.traits["host"]
            # startStatus = obj.traits["domesticstatus"]
            startLat = obj.traits["location1"]
            startLong = obj.traits["location2"]
            
            for child in children:
                node2 = child.label
                endYear = MRSD - obj.traits["height"]
                # endFly = child.traits["flyway"]
                endLatGrp = child.traits["region"]
                # endOrder = child.traits["corrected_order"]
                endOrder = child.traits["host"]
                # endStatus = child.traits["domesticstatus"]
                endLat = child.traits["location1"]
                endLong = child.traits["location2"]
                tip = getattr(child, 'name', pd.NA)
                
                metadata.append({
                    "node1": node1,
                    "node2": node2,
                    "length": length,
                    "startYear": startYear,
                    "endYear": endYear,
                    "startLat": startLat,
                    "startLon": startLong,
                    "endLat": endLat,
                    "endLon": endLong,
                    # "startFlyway": startFly,
                    # "endFlyway": endFly,
                    "startRegion": startLatGrp,
                    "endRegion": endLatGrp,
                    "startHost": startOrder,
                    "endHost": endOrder,
                    # "startStatus": startStatus,
                    # "endStatus": endStatus,
                    "tipLabel": tip
                    }) 
            # count += 1
                    
        else:
            pass

    df = pd.DataFrame(metadata)

    return(df)

# %%
# eq-time-host-1000 - 2024.8989071038252
# eq-time-host-3000 - 2024.8989071038252
# prop-time-loc - 2024.9453551912568
# prop-time-host - 2024.9453551912568
# liveharvest - 2025.0438356164384
# Eq-time-loc - 2025.054794520548

# A1/2 - 2024.2513661202186
# A3 - 2025.0602739726028
# B3.2 - 2024.983606557377
# B3.6 - 2025.3397260273973
# C2.1 - 2024.3934426229507
# D1.1 - 2025.695890410959

# H5N5 summer 2026 - 2026.0520547945205

df = nexus_to_metadata(tree, 2026.0520547945205)

# %%
print(len(df))
df.head(15)
# Out:
# 722
#     node1  node2    length    startYear      endYear   startLat   startLon  \
# 0       0      1  0.000000  2020.470779  2020.470779  66.706040  64.264691
# 1       0      4  0.000000  2020.470779  2020.470779  66.706040  64.264691
# 2       1      3  0.750505  2021.223421  2021.223421  66.763335  92.847569
# 3       1      2  0.750505  2021.223421  2021.223421  66.763335  92.847569
# 4       4    722  0.852075  2021.331666  2021.331666  66.454691  21.051927
# 5       4      5  0.852075  2021.331666  2021.331666  66.454691  21.051927
# 6       5      6  0.199109  2021.508931  2021.508931  64.152085  12.665997
# 7       5      9  0.199109  2021.508931  2021.508931  64.152085  12.665997
# 8       6      7  0.119584  2021.632914  2021.632914  64.041794  12.428655
# 9       6      8  0.119584  2021.632914  2021.632914  64.041794  12.428655
# 10      9     10  0.125835  2021.662494  2021.662494  64.004359  12.059363
# 11      9     13  0.125835  2021.662494  2021.662494  64.004359  12.059363
# 12     10     12  0.061778  2021.738576  2021.738576  64.041197  12.076196
# 13     10     11  0.061778  2021.738576  2021.738576  64.041197  12.076196
# 14     13    615  0.073240  2021.766308  2021.766308  64.132092  10.400069
#
#        endLat     endLon startRegion endRegion startHost endHost  \
# 0   66.763335  92.847569      europe    europe       gds     gds
# 1   66.454691  21.051927      europe    europe       gds    seab
# 2   66.755399  93.849104      europe    europe       gds     gds
# 3   66.755397  93.849770      europe    europe       gds     gds
# 4   78.636412  21.990782      europe    europe      seab    seab
# 5   64.152085  12.665997      europe    europe      seab    bdpr
# 6   64.041794  12.428655      europe    europe      bdpr    bdpr
# 7   64.004359  12.059363      europe    europe      bdpr    bdpr
# 8   63.988410  12.306264      europe    europe      bdpr    bdpr
# 9   63.989398  12.307109      europe    europe      bdpr    bdpr
# 10  64.041197  12.076196      europe    europe      bdpr    bdpr
# 11  64.132092  10.400069      europe    europe      bdpr    seab
# 12  63.989037  12.311570      europe    europe      bdpr    bdpr
# 13  63.989337  12.308514      europe    europe      bdpr    bdpr
# 14  63.804228   2.379933      europe    europe      seab    seab
#
#                                              tipLabel
# 0                                                 NaN
# 1                                                 NaN
# 2   EPI_ISL_16209277|A/shelduck/Kalmykia/1814-1/20...
# 3   EPI_ISL_16209278|A/waterfowl/Russia/1526-4/202...
# 4   EPI_ISL_18963366|A/Great_skua/Norway/2022-07-1...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   EPI_ISL_18901717|A/White-tailed_eagle/Norway/2...
# 9   EPI_ISL_18860084|A/White-tailed_eagle/Norway/2...
# 10                                                NaN
# 11                                                NaN
# 12  EPI_ISL_18901686|A/White-tailed_eagle/Norway/2...
# 13  EPI_ISL_18901641|A/White-tailed_eagle/Norway/2...
# 14                                                NaN

# %%
# df.to_csv("../SERAPHIM/nov2021-2024_no-suliformes/process_dta/NAm_wild-aves_nov2021-2024_no-suliformes_ha_flyway-latgrp-order_MCC.csv", sep = ',')
# df.to_csv("../BEAST/continuous_phylogeography/results/2025-09-24_nov2021-2024_no-suliformes_ha_contphyl_order-DTA_thorney/NAm_wild-aves_nov2021-2024_no-suliformes_contphyl-order_MCC.csv", sep = ',')
# df.to_csv("../SERAPHIM/nov2021-2024_no-suliformes_contphyl-orderDTA/NAm_wild-aves_nov2021-2024_no_suliformes_ha_contphyl_order-DTA_MCC.csv", sep = ',')
# df.to_csv("../SERAPHIM/nov2021-2024_no-suliformes_contphyl-duckgoose-DTA/NAm_wild-aves_nov2021-2024_no-suliformes_ha_contphyl_duckgoose-DTA_MCC.csv", sep = ',')
# df.to_csv("../SERAPHIM/nov2021-2024_no-suliformes_DTA/order_dta/NAm_wild-aves_nov2021-2024_no-suliformes_ha_contphyl_order-DTA_MCC.csv", sep = ',')
# df.to_csv("../SERAPHIM/nov2021-2024_no-suliformes_DTA/duckduckgoose_dta/NAm_wild-aves_nov2021-2024_no-suliformes_ha_contphyl_ddg-DTA_MCC.csv", sep = ',')
# df.to_csv("../../H5N5-mini-project/SERAPHIM/A6_concat-genome_traits_2026-03-01_MCC.csv", sep = ",")
# df.to_csv("../../H5N5-mini-project/SERAPHIM/A6_concat-genome_traits_2026-03-10_MCC.csv", sep = ",")
# df.to_csv("../SERAPHIM/main-intro_equal-time-host-3000/main-intro_equal-time-host-3000_ha_traits_MCC.csv", sep = ",")
# df.to_csv("../SERAPHIM/main-intro_equal-time-host-1000/main-intro_equal-time-host-1000_ha_traits_MCC.csv", sep = ",")
# df.to_csv("../SERAPHIM/main-intro_prop-time-loc/main-intro_prop-time-loc_ha_traits_MCC.csv", sep = ",")
# df.to_csv("../SERAPHIM/main-intro_prop-time-host/main-intro_prop-time-host_ha_traits_noLP_MCC.csv", sep = ",")
# df.to_csv("../SERAPHIM/main-intro_liveharvest/main-intro_liveharvest_ha_traits_MCC.csv", sep = ",")
# df.to_csv("../../H5-genotypes/SERAPHIM/h5_A1_A2_exponential_traits/A1_A2_ha_exponential_traits_MCC.csv", sep = ",")
# df.to_csv("../../H5-genotypes/SERAPHIM/h5_A3_exponential_traits/A3_ha_exponential_traits_MCC.csv", sep = ",")
# df.to_csv("../../H5-genotypes/SERAPHIM/h5_B3.2_exponential_traits/B3.2_ha_exponential_traits_MCC.csv", sep = ",")
# df.to_csv("../../H5-genotypes/SERAPHIM/h5_B3.6_exponential_traits/B3.6_ha_exponential_traits_MCC.csv", sep = ",")
# df.to_csv("../../H5-genotypes/SERAPHIM/h5_C2.1_exponential_traits/C2.1_ha_exponential_traits_MCC.csv", sep = ",")
# df.to_csv("../../H5-genotypes/SERAPHIM/h5_D1.1_exponential_traits/D1.1_ha_exponential_traits_MCC.csv", sep = ",")
# df.to_csv("../SERAPHIM/main-intro_equal-time-loc/main-intro_equal-time-loc_ha_traits_MCC.csv", sep = ",")
# df.to_csv("../../H5N5-seabird-phylo/SERAPHIM/A6_concat-gen_traits_2026-07-09_MCC.csv", sep = ",")
df.to_csv("../../H5N5-seabird-phylo/SERAPHIM/A6_concat-gen_traits_2026-08-04_MCC.csv", sep = ",")

# %%
# Feel free to ignore all the code below! 
# Its me troubleshooting
# And I don't wanna delete it cause What If

# %%
# This code chunck is good for checking which objects are nodes and which are tips in a small tree

# doublecheckdict = {}

# for k in tree.Objects:
#     if k.is_node():
#         doublecheckdict.update({k.label:"node"})
#     elif k.is_leaf():
#         doublecheckdict.update({k.label:k.name})
#     else:
#         print("what")

# print(doublecheckdict)

# %%
# print(list(tree.Objects[0].traits.keys()))
print(list(tree.Objects[2].traits.keys()))
# print(list(tree.Objects[5].traits.keys()))
# print(tree.Objects[4].height)
# Out:
# ['corrected_order.rate_median', 'corrected_order', 'location.rate_median', 'height_median', 'location.rate', 'length_median', 'height', 'location2_median', 'corrected_order.prob', 'location1_median', 'length', 'posterior', 'corrected_order.rate', 'location1', 'location2', 'length_range', 'height_range', 'location1_range', 'corrected_order.set.prob', 'corrected_order.rate_range', 'location.rate_range', 'location1_80%HPD_3', 'location1_80%HPD_2', 'location1_80%HPD_1', 'length_95%_HPD', 'corrected_order.rate_95%_HPD', 'height_95%_HPD', 'location.rate_95%_HPD', 'location2_80%HPD_1', 'corrected_order.set', 'location2_80%HPD_2', 'location2_80%HPD_3', 'location2_range']

# %%
# This code chunck was where I was troubleshooting how to get the date of each object

most_recent_sampling_date = 2024.9262295081967

test_meta = []

for obj in tree.Objects:
    children = []

    tree_max_height = max(obj.height for obj in tree.Objects)

    if obj.is_node():
        children.extend(obj.children) # Use .extend instead of .append, the former makes a flat list while the latter appends a list into the list
        # node1 = obj
        node1 = obj.label
        height_trait = obj.traits["height"] # Height relative to absolute time
        height = obj.height # Height relative to the other nodes and tips?
        length_trait = obj.traits["length"]
        length = obj.length
        startYear1 = most_recent_sampling_date - obj.traits["height"]
        startYear2 = most_recent_sampling_date - (tree_max_height - obj.height)
        startYear3 = obj.absoluteTime
        
        for child in children:
            node2 = child.label
            node2_height_trait = child.traits["height"]
            node2_height = child.height
            node2_length_trait = child.traits["length"]
            node2_length = child.length
            total_length = length + node2_length
            endYear_1 = most_recent_sampling_date - child.traits["height"]
            endYear_3 = child.absoluteTime # still not the exact same as endYear_1, but VERY close

            # print(child, child.name, child.traits["height"], child.traits["length"], endYear_1, endYear_2)
            # print(child.parent, child.parent.traits["height"], child.parent.traits["length"])
            negative_time = endYear_1 - startYear1
           
            test_meta.append({
                "node1": node1,
                "node2": node2,
                # "node1_heighttrait": height_trait,
                # "node1_height": height,
                # "node1_lengthtrait": length_trait,
                # "node1_length": length,
                # "node2_heightrait": node2_height_trait,
                # "node2_height": node2_height,
                # "node2_lengthtrait": node2_length_trait,
                # "node2_length": node2_length,
                # "length": total_length,
                "startYear_good": startYear1,
                "startYear_testing": startYear3,
                "endYear_good": endYear_1,
                "endYear_testing": endYear_3,
                "negativeTime": negative_time
                }) 
                
    else:
        pass

# %%
test_df = pd.DataFrame(test_meta)

pd.set_option('display.max_rows', None)
test_df_tips = test_df[test_df["node2"].isin([19, 20, 22, 23, 24, 25, 26, 29, 30, 31, 33, 34, 35, 36, 37, 39, 40, 44, 45, 46, 47,
                                             54, 55, 56, 58, 59, 60, 63, 64, 65, 67, 68, 70, 71, 72, 73, 75, 76, 78, 79, 83, 84, 85, 86])]
print(test_df[0:20])

#test_df.to_csv("./testing_heightlength.tsv", sep = '\t')
# Out:
#     node1  node2  startYear_good  startYear_testing  endYear_good  \
# 0       0     80     2023.625109        2023.625109   2023.687715
# 1       0      1     2023.625109        2023.625109   2023.663333
# 2       1     77     2023.663333        2023.638340   2023.731289
# 3       1      2     2023.663333        2023.638340   2023.731763
# 4       2     74     2023.731763        2023.725194   2023.765866
# 5       2      3     2023.731763        2023.725194   2023.836136
# 6       3     73     2023.836136        2023.893871   2024.120219
# 7       3      4     2023.836136        2023.893871   2023.889390
# 8       4     72     2023.889390        2023.916366   2023.923288
# 9       4      5     2023.889390        2023.916366   2024.122246
# 10      5     69     2024.122246        2024.071469   2024.276561
# 11      5      6     2024.122246        2024.071469   2024.169386
# 12      6     48     2024.169386        2024.171942   2024.198201
# 13      6      7     2024.169386        2024.171942   2024.179633
# 14      7     41     2024.179633        2024.175978   2024.185305
# 15      7      8     2024.179633        2024.175978   2024.188175
# 16      8     38     2024.188175        2024.189065   2024.202919
# 17      8      9     2024.188175        2024.189065   2024.197027
# 18      9     37     2024.197027        2024.201582   2024.210383
# 19      9     10     2024.197027        2024.201582   2024.204491
#
#     endYear_testing  negativeTime
# 0       2023.667379      0.062606
# 1       2023.638340      0.038224
# 2       2023.638550      0.067955
# 3       2023.725194      0.068430
# 4       2023.824569      0.034103
# 5       2023.893871      0.104373
# 6       2024.120217      0.284083
# 7       2023.916366      0.053254
# 8       2023.923286      0.033897
# 9       2024.071469      0.232856
# 10      2024.299971      0.154315
# 11      2024.171942      0.047140
# 12      2024.196507      0.028815
# 13      2024.175978      0.010247
# 14      2024.181090      0.005672
# 15      2024.189065      0.008542
# 16      2024.207763      0.014743
# 17      2024.201582      0.008851
# 18      2024.210383      0.013356
# 19      2024.203401      0.007464

# %%
#print(len(test_df[test_df["node2_length"] < 0]))

# %%
# test_df_negtime = test_df[test_df["endYear_testing"] < test_df["startYear_testing"]]

#test_df_negtime["change"] = test_df_negtime["endYear_good"] - test_df_negtime["startYear"]

#print(test_df_negtime)
# print(len(test_df_negtime))

# %%
# This code chunk prints the parent and child (and corresponding heights) for each pair where the child height is greater than parent height

# for obj in tree.Objects:
#     if obj.is_node():
#         for child in obj.children:
#             if child.traits["height"] > obj.traits["height"]:
#                 print(f"{obj.label} → {child.label}: PARENT ({obj.traits['height']}) < CHILD ({child.traits['height']}) ❌")

# %%
# import matplotlib.pyplot as plt

# def plot_nexus(mytree, save_path):

#     plt.rcParams["font.family"] = "Arial"

#     fig,ax = plt.subplots(figsize=(10,20),facecolor='w')
        
#     x_attr=lambda k: k.absoluteTime
    
#     # for k in mytree.getExternal(): # Extract the flyway for each tip name using the name_to_flyway dictionary
#     #     flyway = name_to_flyway.get(k.name, None)  # None if no match
#     #     k.flyway = flyway

#     def color_by(k): # New color-by function 
#         if k.is_node():
#             for child in k.children:
#                 if child.traits["height"] > k.traits["height"]:
#                     return "#FF0303"
#         return "#5E5E5E"
#         # if hasattr(k, 'flyway') and k.flyway in flyway_colors:
#         #     return flyway_colors[k.flyway]
#         # return '#898989'  # default color
    
#     mytree.plotTree(ax,x_attr=x_attr, colour=color_by) ## tree
#     mytree.plotPoints(ax,
#                       x_attr=x_attr,
#                       size=30,
#                       colour="#5E5E5E",
#                       zorder=100)
#     ax.plot() ## need to call plot when only drawing the tree to force drawing of line collections

#     # # # If you want tree annotations
#     # # # target_func=lambda k: k.is_leaf() ## which branches will be annotated
#     # # # text_func=lambda k: k.traits['rea'] if k.traits['is_reassorted'] else "" ## what text is plotted
#     # # # text_x_attr=lambda k: k.x+0.003 ## where x coordinate for text is
#     # # # mytree.addText(ax,x_attr=text_x_attr,target=target_func,text=text_func, size='10')

#     # If you want the legend in the tree
#     # legend_handles = [Patch(color=color, label=NAflyway) for NAflyway, color in flyway_colors.items()]
#     # legend = ax.legend(handles=legend_handles, title="$\\bf{Flyway}$", loc="center right", fontsize='15')
#     # plt.setp(legend.get_title(),fontsize=25)

#     # # # If you want a scale bar
#     # # # scale_length = 0.01
#     # # # x_min, x_max = ax.get_xlim()
#     # # # scale_x_start = x_min + (x_max - x_min) * 0.1
#     # # # scale_x_end = scale_x_start + scale_length * (x_max - x_min)
#     # # # scale_y = 0.05 * (ax.get_ylim()[1] - ax.get_ylim()[0]) + ax.get_ylim()[0]
    
#     # ax.plot([scale_x_start, scale_x_end], [scale_y, scale_y], color='black', lw=2)
#     # ax.text((scale_x_start + scale_x_end) / 2, scale_y, f'{scale_length}', 
#     #         ha='center', va='bottom', fontsize=15)
    
#     ax.set_yticks([])
#     ax.set_yticklabels([])
#     [ax.spines[loc].set_visible(False) for loc in ax.spines if loc not in ['bottom']]
#     ax.tick_params(axis='x',labelsize=10,size=15, width=2,color='grey')
#     fig.tight_layout()
#     # plt.savefig(save_path)
#     # plt.show()

# %%
# plot_nexus(tree, "../SERAPHIM/nov2021-2024_no-suliformes_contphyl-orderDTA/tree_negativetimebranches.pdf")
